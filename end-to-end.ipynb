# %%
import pandas as pd

rt = pd.read_csv("RT_IOT2022.csv")

# %%
rt
# Out:
#           no  id.orig_p  id.resp_p proto service  flow_duration  fwd_pkts_tot  \
# 0          0      38667       1883   tcp    mqtt      32.011598             9
# 1          1      51143       1883   tcp    mqtt      31.883584             9
# 2          2      44761       1883   tcp    mqtt      32.124053             9
# 3          3      60893       1883   tcp    mqtt      31.961063             9
# 4          4      51087       1883   tcp    mqtt      31.902362             9
# ...      ...        ...        ...   ...     ...            ...           ...
# 123112  2005      59247      63331   tcp       -       0.000006             1
# 123113  2006      59247      64623   tcp       -       0.000007             1
# 123114  2007      59247      64680   tcp       -       0.000006             1
# 123115  2008      59247      65000   tcp       -       0.000006             1
# 123116  2009      59247      65129   tcp       -       0.000006             1
#
# ...

# %%
rt.sort_values("Attack_type")
# Out:
#          no  id.orig_p  id.resp_p proto service  flow_duration  fwd_pkts_tot  \
# 15973  3466      43453        443   udp       -       6.166806            13
# 14264  1757      41742        443   tcp     ssl      12.743477            93
# 14265  1758      45059         53   udp     dns       0.083216             2
# 14266  1759      34007         53   udp     dns       0.000835             2
# 14267  1760      48058        443   tcp     ssl     569.142834           392
# ...     ...        ...        ...   ...     ...            ...           ...
# 12344    90      52205        443   tcp       -       0.000000             1
# 12345    91      52205        443   tcp       -       0.000000             1
# 12346    92      45210         53   udp     dns       0.008198             1
# 12333    79      50173       6668   tcp     irc      57.139858            27
# 12506   252      59766       6667   udp       -   21728.335578          4345
#
# ...

# %%
rt.describe()
# Out:
#                   no      id.orig_p      id.resp_p  flow_duration  \
# count  123117.000000  123117.000000  123117.000000  123117.000000
# mean    37035.089248   34639.258738    1014.305092       3.809566
# std     30459.106367   19070.620354    5256.371994     130.005408
# min         0.000000       0.000000       0.000000       0.000000
# 25%      6059.000000   17702.000000      21.000000       0.000001
# 50%     33100.000000   37221.000000      21.000000       0.000004
# 75%     63879.000000   50971.000000      21.000000       0.000005
# max     94658.000000   65535.000000   65389.000000   21728.335578
#
#         fwd_pkts_tot   bwd_pkts_tot  fwd_data_pkts_tot  bwd_data_pkts_tot  \
# count  123117.000000  123117.000000      123117.000000      123117.000000
# mean        2.268826       1.909509           1.471218           0.820260
# std        22.336565      33.018311          19.635196          32.293948
# min         0.000000       0.000000           0.000000           0.000000
# ...

# %%
rt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123117 entries, 0 to 123116
# Data columns (total 85 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   no                        123117 non-null  int64
#  1   id.orig_p                 123117 non-null  int64
#  2   id.resp_p                 123117 non-null  int64
#  3   proto                     123117 non-null  object
#  4   service                   123117 non-null  object
#  5   flow_duration             123117 non-null  float64
#  6   fwd_pkts_tot              123117 non-null  int64
#  7   bwd_pkts_tot              123117 non-null  int64
#  8   fwd_data_pkts_tot         123117 non-null  int64
#  9   bwd_data_pkts_tot         123117 non-null  int64
#  10  fwd_pkts_per_sec          123117 non-null  float64
#  11  bwd_pkts_per_sec          123117 non-null  float64
#  12  flow_pkts_per_sec         123117 non-null  float64
# ...

# %%
attack_mqqt = pd.DataFrame(rt.Attack_type[lambda x: for x in rt.Attack_type["MQTT_Publish"] ])

attack_mqqt
# Out:
#   Cell In[68], line 1
#     attack_mqqt = pd.DataFrame(rt.Attack_type[lambda x: for x in rt.Attack_type["MQTT_Publish"] ])
#                                                         ^
# SyntaxError: invalid syntax

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("supplejade/rt-iot2022real-time-internet-of-things")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\tipqc\.cache\kagglehub\datasets\supplejade\rt-iot2022real-time-internet-of-things\versions\3

# %%
int(rt["id.orig_p"].mean())
# Out:
# 34639

# %%
rt= rt.rename(columns= {"id.orig_p":"victim","id.resp_p":"attacker"})

# %%
rt
# Out:
#           no  victim  attacker proto service  flow_duration  fwd_pkts_tot  \
# 0          0   38667      1883   tcp    mqtt      32.011598             9
# 1          1   51143      1883   tcp    mqtt      31.883584             9
# 2          2   44761      1883   tcp    mqtt      32.124053             9
# 3          3   60893      1883   tcp    mqtt      31.961063             9
# 4          4   51087      1883   tcp    mqtt      31.902362             9
# ...      ...     ...       ...   ...     ...            ...           ...
# 123112  2005   59247     63331   tcp       -       0.000006             1
# 123113  2006   59247     64623   tcp       -       0.000007             1
# 123114  2007   59247     64680   tcp       -       0.000006             1
# 123115  2008   59247     65000   tcp       -       0.000006             1
# 123116  2009   59247     65129   tcp       -       0.000006             1
#
#         bwd_pkts_tot  fwd_data_pkts_tot  bwd_data_pkts_tot  ...  active.std  \
# ...

# %%
rt["Attack_type"].value_counts()
# Out:
# Attack_type
# DOS_SYN_Hping                 94659
# Thing_Speak                    8108
# ARP_poisioning                 7750
# MQTT_Publish                   4146
# NMAP_UDP_SCAN                  2590
# NMAP_XMAS_TREE_SCAN            2010
# NMAP_OS_DETECTION              2000
# NMAP_TCP_scan                  1002
# DDOS_Slowloris                  534
# Wipro_bulb                      253
# Metasploit_Brute_Force_SSH       37
# NMAP_FIN_SCAN                    28
# Name: count, dtype: int64

# %%
iot=rt[["Attack_type","victim","attacker"]]

# %%
iot
# Out:
#                 Attack_type  victim  attacker
# 0              MQTT_Publish   38667      1883
# 1              MQTT_Publish   51143      1883
# 2              MQTT_Publish   44761      1883
# 3              MQTT_Publish   60893      1883
# 4              MQTT_Publish   51087      1883
# ...                     ...     ...       ...
# 123112  NMAP_XMAS_TREE_SCAN   59247     63331
# 123113  NMAP_XMAS_TREE_SCAN   59247     64623
# 123114  NMAP_XMAS_TREE_SCAN   59247     64680
# 123115  NMAP_XMAS_TREE_SCAN   59247     65000
# 123116  NMAP_XMAS_TREE_SCAN   59247     65129
#
# [123117 rows x 3 columns]

# %%
iot.to_csv("iot.csv",)
